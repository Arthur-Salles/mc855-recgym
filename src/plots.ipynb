# %%
import matplotlib.pyplot as plt 


plt.style.use('ggplot')

# %%
## knn best values 
soma_k = [0.938,  0.936,  0.9075,  0.9075,  0.9075]
med_k = [0.5, 0.55,  0.640,  0.67,  0.678]

plt.plot(soma_k, marker='o', label='SOMA')
plt.plot(med_k, marker='o', label = 'MEDIA')
plt.xticks([0, 1, 2, 3, 4], labels=[1,3,5,7,9], fontsize=14)
plt.legend(fontsize=18)
plt.xlabel("K", fontsize=18)
plt.ylabel("F1 Score ", fontsize=18)
plt.yticks(fontsize=14)
# Out:
# (array([0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1. ]),
#  [Text(0, 0.4, '0.4'),
#   Text(0, 0.5, '0.5'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.7000000000000001, '0.7'),
#   Text(0, 0.8, '0.8'),
#   Text(0, 0.9, '0.9'),
#   Text(0, 1.0, '1.0')])
